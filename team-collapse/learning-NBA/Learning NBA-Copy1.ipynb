# %%
import pickle
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
import copy

# %%
np.random.seed(42)
teams = ['BKN', 'MIL', 'GSW', 'LAL', 'IND', 'CHA', 'CHI', 'DET',
          'WAS', 'TOR', 'BOS', 'NYK', 'CLE', 'MEM', 'PHI', 'NOP',
          'HOU','MIN', 'ORL', 'SAS', 'OKC', 'UTA', 'SAC', 'POR',
          'DEN', 'PHX', 'DAL', 'ATL', 'MIA', 'LAC']
teams.reverse()
window = 4 # 4 samples per game (one sample / quarter)

# %%
N_players = 5
players = [f'player{i}' for i in range(1, N_players+1)]
n_components = 3 # num of hidden states
n_features = 3 # num of observed states
O_symbols = [0, 1, 2] # under-, avg-, over- performance
H_symbols = [0, 1, 2] # corresponding mental states
T = 100
learning_iterations = 100
initial_dist = np.array([0, 1, 0])

# %%
# === M ===
avg_transO = np.array([[0.5, 0.3, 0.2],
                       [0.25, 0.5, 0.25],
                       [0.2, 0.3, 0.5]])

star_transO = np.array([[0.7, 0.3, 0],
                        [0.1, 0.8, 0.1],
                        [0, 0.3, 0.7]])
# === N ===
avg_transH = np.array([[0.8, 0.2, 0.0],
                       [0.1, 0.8, 0.1],
                       [0.0, 0.2, 0.8]])

# === emission_prob ===
avg_emission = np.array([[0.7, 0.3, 0],
                       [0.1, 0.8, 0.1],
                       [0.0, 0.3, 0.7]])

# ===  R ===
R_singleH = np.array([1] + [0] * len(players))
def R_singleHO(player):
    i = int(player[-1])
    arr = [0] * (len(players)+1)
    arr[0] = 0.7
    arr[i] = 0.3
    return np.array(arr)

def R_singleO(player):
    i = int(player[-1])
    arr = [0] * (len(players)+1)
    arr[i] = 1
    return np.array(arr)

def R_star(player, star):
    if player == star:
        return R_singleH
    arr = [0] * (len(players)+1)
    i = int(star[-1])
    arr[i] = 1
    return np.array(arr)
    
R_uniform = np.array([1/(1 + len(players))] * (len(players) + 1))

# %%
def init_trans():
    trans_mat = np.zeros((n_components, n_components))
    
    trans_mat[0][0] = np.random.uniform(0.5, 1)
    trans_mat[0][1] = 1 - trans_mat[0][0]
    trans_mat[0][2] = 0.0
    
    trans_mat[1][1] = np.random.uniform(0.5, 1)
    trans_mat[1][0] = (1 - trans_mat[1][1]) / 2
    trans_mat[1][2] = (1 - trans_mat[1][1]) / 2
    
    trans_mat[2][2] = np.random.uniform(0.5, 1)
    trans_mat[2][0] = 0.0
    trans_mat[2][1] = 1 - trans_mat[2][2]
    
    return trans_mat

def init_random():
    mat = np.random.random((n_features, n_components))
    for i in range(n_features):
        mat[i] = mat[i] / np.sum(mat[i])
    return mat

def init_R():
    R = dict()
    for p in players:
        # populate R[p] with random numbers
        R[p] =  np.random.rand(N_players + 1)
        
        # randomly select entries and set them to 0
        nums = np.random.choice(range(N_players + 1), np.random.choice(range(N_players)), replace=False)
        for i in nums:
            R[p][i] = 0
            
        # normalize
        R[p] = R[p] / np.sum(R[p])
    
    return R

# %%
def cond(player, h1, h2, t, M_, N_, R_): # P(H_t^player = h1 | H_{t-1}^player = h2, O_{t-1})    
    # Requires M_, N_, R_, Os
    v = [N_[h2][h1]]
    for teammate in players:
        v.append(M_[Os[teammate][t-1]][h1])
            
    v = np.array(v)
    return np.dot(R_[player], v)

# %%
def learn_R(M, N, samples, O):
    R = {p: cp.Variable(len(players) + 1, nonneg=True) for p in players}

    objective = 0
    for H in samples:
        for p in players:
            for t in range(1, T):
                h_t = H[p][t] # state of player p at time t
                v_t = [N[H[p][t-1]][h_t]]
                for teammate in players:
                    v_t.append(M[O[teammate][t-1]][h_t])
                v_t = np.array(v_t)
                prod = R[p] @ v_t
                objective -= cp.log(prod)

    R_constraints = [cp.sum(R[p]) == 1 for p in R]
    prob = cp.Problem(cp.Minimize(objective), R_constraints)
    prob.solve(solver=cp.MOSEK)
    
    R_optimized = {p: R[p].value for p in players}
    
    return R_optimized, prob.value

# %%
def learn_M_N(R, samples, O):
    M = cp.Variable((n_features, n_components), nonneg=True)
    N = cp.Variable((n_components, n_components), nonneg=True) 
    E = cp.Variable((n_components, n_features), nonneg=True)
    
    objective = 0
    for H in samples:
        for p in players:
            for t in range(1, T):
                h_t = H[p][t] # state of player p at time t
                v_t = [2*N[H[p][t-1], h_t]]
                for teammate in players:
                    v_t.append(M[O[teammate][t-1], h_t])
                v_t = np.array(v_t)
                prod = R[p] @ v_t
                objective -= cp.log(prod)
    
    M_constraints = [cp.sum(M[i, :]) == 1 for i in range(n_features)]
    N_constraints = [cp.sum(N[i, :]) == 1 for i in range(n_components)]
    
    constraints = M_constraints + N_constraints
    prob = cp.Problem(cp.Minimize(objective), constraints)
    prob.solve(solver=cp.MOSEK)
    
    M_optimized = M.value
    N_optimized = N.value
    
    return M_optimized, N_optimized, prob.value

# %%
def learn_E(samples, O):
    E = cp.Variable((n_components, n_features), nonneg=True)
    
    objective = 0
    for H in samples:
        for p in players:     
            for t in range(T):
                objective -= cp.log(E[H[p][t]][O[p][t]])
                
    E_constraints = [cp.sum(E[i, :]) == 1 for i in range(n_components)]
    prob = cp.Problem(cp.Minimize(objective), E_constraints)
    prob.solve(solver=cp.MOSEK)
    E_optimized = E.value
    
    return E_optimized, prob.value

# %%
def calculate_forward(M_, N_, E_, R_):
    alpha = {p: [] for p in players}
    alpha_help = {p: [] for p in players}
    
    # Initialize forward parameters
    for p in players:
        alpha_help[p].append(initial_dist)
    for p in players:
        arr = np.array([E_[h][Os[p][0]] * alpha_help[p][0][h] for h in H_symbols])
        arr /= np.sum(arr)
        alpha[p].append(arr)

    # Compute forward parameters (bottom-up)
    for p in players:
        for t in range(1, T):
            if t % 4 == 0:
                alpha_help[p].append(initial_dist)
                alpha[p].append(initial_dist)
                continue
                
            arr = [sum([cond(p, h, h_, t, M_, N_, R_) * alpha[p][t-1][h_] for h_ in H_symbols]) for h in H_symbols]
            arr = np.array(arr)
            alpha_help[p].append(arr)
            
            arr = [E_[h][Os[p][t]] * alpha_help[p][t][h] for h in H_symbols]
            arr = np.array(arr)
            arr /= np.sum(arr)
            alpha[p].append(arr)
            
    return alpha, alpha_help

# %%
def E_step(M_, N_, E_, R_, num_of_samples = 10):
    alpha, alpha_help = calculate_forward(M_, N_, E_, R_)
    
    # Sample hidden states from the posterior distribution
    samples = []
    for _ in range(num_of_samples):
        Hs_ = {p: [1] for p in players}

        for p in players:
            for t in range(1, T):
                dist = np.array([alpha[p][t][h] * cond(p, h, Hs_[p][t-1], t, M_, N_, R_) / alpha_help[p][t][h] if alpha_help[p][t][h] != 0 else 0 for h in H_symbols])
                dist /= np.sum(dist)
                Hs_[p].append(np.random.choice(H_symbols, p=dist))
        for p in players:
            Hs_[p] = np.array(Hs_[p])
        samples.append(copy.deepcopy(Hs_))
    
    return samples

def M_step(samples, M, N, R, E, iterations=1):
    M_opt = M
    N_opt = N
    R_opt = copy.deepcopy(R)
    E_opt = E
    val = 1e+100
    for _ in range(iterations):
        try:
#             R_opt, val1 = learn_R(M_opt, N_opt, samples, Os) # Fix M, N and maximize R, E
#             M_opt, N_opt, val1 = learn_M_N(R_opt, samples, Os) # Fix R and maximize M, N, E

            M_opt, N_opt, val1 = learn_M_N(R_opt, samples, Os) # Fix R and maximize M, N, E
            R_opt, val1 = learn_R(M_opt, N_opt, samples, Os) # Fix M, N and maximize R, E
            E_opt, val2 = learn_E(samples, Os)
            
            val = (val1 + val2) / len(samples)
        except cp.error.SolverError as e:
            print(e)
            break
            
    return M_opt, N_opt, R_opt, E_opt, val

def EM(params, iterations = 30, reltol = 1e-3, inctol = 2):
    # Initialize parameters
    M_, N_, E_, R_ = params['M'], params['N'], params['E'], params['R']
    
    cntObjIncreasing = 0
    val = 1e+100 # best objective value achieved so far
    M_opt = M_
    N_opt = N_
    E_opt = E_
    R_opt = copy.deepcopy(R_)
    for i in range(iterations):
        print(f'=== EM iteration {i+1} ===')
        # E-step
        print(f'E-step...')
        samples = E_step(M_, N_, E_, R_)
        
        
        # M-step
        print(f'M-step...')
        M_, N_, R_, E_, obj_val = M_step(samples, M_, N_, R_, E_)
        
            
        print(f'\tObjVal = {obj_val}')
        # Update current best parameters
        if obj_val < val:
            M_opt = M_
            N_opt = N_
            E_opt = E_
            R_opt = copy.deepcopy(R_)
        
        # Stopping conditions
        if abs(val - obj_val) / val < reltol and obj_val < val:
            break
        
        cntObjIncreasing = 0 if obj_val <= val else cntObjIncreasing + 1
        if cntObjIncreasing > inctol:
            break
            
        # Update best objective value so far    
        val = min(val, obj_val)
        
    return M_opt, N_opt, R_opt, E_opt, val

# %%
def EM_helper(param_list):
    i = 1
    val_opt = 1e+100
    for params in param_list:
        print(f'==== EM run {i} ====')
        i += 1
        M_, N_, R_, E_, val = EM(params)
        
        if val < val_opt:
            val_opt = val
            M_opt = M_
            N_opt = N_
            E_opt = E_
            R_opt = R_
            
    return M_opt, N_opt, R_opt, E_opt, val_opt

# %%
def print_params(M_, N_, E_, R_):
    print(f'M = {np.round(M_, 2)}')
    print(f'N = {np.round(N_, 2)}')
    print(f'E = {np.round(E_, 2)}')
    for p in players:
        print(f'R[{p}] = {np.round(R_[p], 2)}')

# %%
def likelihood(params): # Calculate log P(O) (given the model parameters)
    M, N, E, R = params['M'], params['N'], params['E'], params['R']

    # Caluclate forward parameters
    alpha, alpha_help = calculate_forward(M, N, E, R)
    obj = 0
    for p in players:
        for t in range(T):
            if isinstance(E, dict):
                obj += -np.log(sum([E[p][h][Os[p][t]] * alpha_help[p][t][h] for h in H_symbols])) # Pr(O_t^i | O_{1:t-1})
            else:
                obj += -np.log(sum([E[h][Os[p][t]] * alpha_help[p][t][h] for h in H_symbols])) # Pr(O_t^i | O_{1:t-1})

    return obj

def likelihood_test(params_list):
    # Given a list of model parameters returns the model parameters that achieve the highest likelihood
    val_opt = 1e+100
    for params in params_list:
        val = likelihood(params)
        if val < val_opt:
            val_opt = val
            params_opt = params
    return params_opt

# %%
for team in teams:
    try:
        print(f'Optimizing team = {team}')
        with open(f'../team-data/observations/{team}_observations.pickle', 'rb') as file:
                observations = pickle.load(file)

        k = list(observations.keys())[0]
        players = list(observations[k].keys())

        Os = {p: [] for p in players}
        for game_id in observations:
            game_stats = observations[game_id]
            for p in players:
                Os[p].extend(game_stats[p])

        with open(f'./profiles2/{team}_profile.pkl', 'rb') as file:
            params = pickle.load(file)

        print(f"Initial Likelihood = {likelihood(params)}")
        print(params)
        M_, N_, R_, E_, val = EM(params, 30)
        print_params(M_, N_, E_, R_)

        print(f"Final Likelihood = {likelihood({'M': M_, 'N': N_, 'E': E_, 'R': R_})}")

        params = dict()
        params['M'] = M_
        params['N'] = N_
        params['E'] = E_
        params['R'] = R_
        with open(f'./results2/{team}_profile.pkl', 'wb') as file:
            pickle.dump(params, file)
            
    except Exception as e:
        print(f'Error for team {team}')
        print(e)
# Out:
# Optimizing team = LAC
# Initial Likelihood = 518.2777717875646
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Eric Bledsoe': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Reggie Jackson': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Terance Mann': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Marcus Morris': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Ivica Zubac': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# /usr3/graduate/nikolaou/.local/lib/python3.10/site-packages/cvxpy/problems/problem.py:157: UserWarning: Objective contains too many subexpressions. Consider vectorizing your CVXPY code to speed up compilation.
#   warnings.warn("Objective contains too many subexpressions. "
# 	ObjVal = 796.6864498663007
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 750.1598714117393
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 711.4529394405619
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 691.5318055635893
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 679.0022020639193
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 663.0700827280352
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 658.4202884741306
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 649.3563455304857
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 643.1581613767437
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 634.5880732366116
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 631.1789326810933
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 630.5697950566855
# M = [[1. 0. 0.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.18 0.79 0.03]
#  [0.07 0.9  0.03]
#  [0.03 0.87 0.1 ]]
# E = [[0.74 0.   0.25]
#  [0.21 0.56 0.23]
#  [0.08 0.   0.92]]
# R[Eric Bledsoe] = [0.19 0.   0.05 0.06 0.7  0.  ]
# R[Reggie Jackson] = [0.6  0.04 0.1  0.   0.26 0.  ]
# R[Terance Mann] = [0.96 0.   0.   0.04 0.   0.  ]
# R[Marcus Morris] = [0. 0. 0. 0. 1. 0.]
# R[Ivica Zubac] = [0.65 0.   0.   0.   0.35 0.  ]
# Final Likelihood = 502.97908460463157
# Optimizing team = MIA
# Initial Likelihood = 585.845244557185
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.9, 0.1, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.1, 0.9]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Kyle Lowry': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Tyler Herro': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Jimmy Butler': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'P.J. Tucker': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Bam Adebayo': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2487'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 873.4160730116258
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 849.4479737239326
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 815.0092517038399
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 784.7427484757416
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 759.2151206201146
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 743.4291610261876
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 728.7536903403159
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 712.5172093036042
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 701.0761923345874
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 683.0893766620225
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 672.7039792546741
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 664.0231491568733
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 663.6070668545739
# M = [[0.   0.   1.  ]
#  [0.   1.   0.  ]
#  [0.99 0.   0.01]]
# N = [[0.   0.95 0.05]
#  [0.04 0.95 0.01]
#  [0.1  0.9  0.  ]]
# E = [[0.78 0.   0.22]
#  [0.24 0.47 0.29]
#  [0.36 0.   0.64]]
# R[Kyle Lowry] = [0.95 0.01 0.01 0.   0.01 0.02]
# R[Tyler Herro] = [0.96 0.   0.01 0.   0.02 0.  ]
# R[Jimmy Butler] = [0.68 0.   0.   0.31 0.   0.  ]
# R[P.J. Tucker] = [0.91 0.   0.02 0.07 0.   0.  ]
# R[Bam Adebayo] = [0.93 0.   0.   0.   0.   0.07]
# Final Likelihood = 530.2569188021595
# Optimizing team = ATL
# Initial Likelihood = 557.9677666046105
# {'M': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'N': array([[0.1, 0.2, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.2, 0.1]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Trae Young': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Bogdan Bogdanovic': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Kevin Huerter': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Danilo Gallinari': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Clint Capela': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-1583'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 892.6601835978006
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 863.382244560316
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 812.4646240966787
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 777.5776097666367
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 759.9722103021805
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 728.730940360058
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 710.1495967110104
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 692.9199536397924
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 675.7259397195254
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 656.381097606229
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 642.5090276760326
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 640.8924499283565
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 638.9186201456076
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 637.2629701578361
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 631.9877362074765
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 628.9886377160544
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 624.4603299103387
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 615.5205678846668
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 606.5801352453759
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 606.8141950892032
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 603.3510469395562
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 601.4369970296067
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 601.3582063204408
# M = [[0.   0.   1.  ]
#  [0.91 0.   0.09]
#  [0.   0.   1.  ]]
# N = [[0.   1.   0.  ]
#  [0.02 0.98 0.  ]
#  [0.03 0.86 0.11]]
# E = [[1.   0.   0.  ]
#  [0.25 0.49 0.26]
#  [0.13 0.   0.87]]
# R[Trae Young] = [0.88 0.03 0.   0.   0.07 0.02]
# R[Bogdan Bogdanovic] = [1. 0. 0. 0. 0. 0.]
# R[Kevin Huerter] = [0.97 0.   0.   0.   0.03 0.  ]
# R[Danilo Gallinari] = [1. 0. 0. 0. 0. 0.]
# R[Clint Capela] = [0.99 0.   0.   0.   0.   0.01]
# Final Likelihood = 524.7495031325009
# Optimizing team = DAL
# Initial Likelihood = 576.044253432791
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.7, 0.2, 0.1],
#        [0.1, 0.7, 0.2],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Luka Doncic': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Jalen Brunson': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Reggie Bullock': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Dorian Finney-Smith': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Dwight Powell': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2939'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 892.5087012220898
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 865.2781176581714
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 825.7920256931615
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 670.1329659801548
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 655.2556814841248
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 636.9310434349215
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 631.5971474623884
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 610.1161013405924
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 594.7749800003919
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 578.2244447846481
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 569.9682665274288
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 570.5811547505806
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 561.386327134712
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 557.1411743740401
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 556.3836560934708
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 550.7448726699489
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 544.7786344678252
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 542.6949500525
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 539.9427376208139
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 540.1025944440887
# === EM iteration 25 ===
# E-step...
# M-step...
# 	ObjVal = 538.3103703764874
# === EM iteration 26 ===
# E-step...
# M-step...
# 	ObjVal = 537.7092409283196
# === EM iteration 27 ===
# E-step...
# M-step...
# 	ObjVal = 537.7366460013184
# === EM iteration 28 ===
# E-step...
# M-step...
# 	ObjVal = 536.5614898723394
# === EM iteration 29 ===
# E-step...
# M-step...
# 	ObjVal = 536.5263181725824
# M = [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 0. 1.]]
# N = [[0. 1. 0.]
#  [0. 1. 0.]
#  [0. 1. 0.]]
# E = [[1.   0.   0.  ]
#  [0.33 0.44 0.23]
#  [0.   0.   1.  ]]
# R[Luka Doncic] = [1. 0. 0. 0. 0. 0.]
# R[Jalen Brunson] = [0.99 0.   0.01 0.   0.   0.  ]
# R[Reggie Bullock] = [1. 0. 0. 0. 0. 0.]
# R[Dorian Finney-Smith] = [1. 0. 0. 0. 0. 0.]
# R[Dwight Powell] = [1. 0. 0. 0. 0. 0.]
# Final Likelihood = 531.8392511126676
# Optimizing team = PHX
# Initial Likelihood = 553.86622226533
# {'M': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'N': array([[0.1, 0.2, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.2, 0.1]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Chris Paul': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Devin Booker': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Mikal Bridges': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Jae Crowder': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Deandre Ayton': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-1583'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 897.4286026102038
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 858.590589327303
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 811.8963814454896
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 778.0928417756389
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 760.4564995588074
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 735.0372350634422
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 709.8487325790771
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 699.8001567538629
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 675.1634238861079
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 663.2275941005665
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 653.7562771054661
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 626.5356217090373
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 630.6488879719702
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 628.7165536858981
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 625.4803307177688
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 620.8316033300267
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 613.9587840135555
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 603.1828555685138
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 598.8272186711296
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 590.1082928389776
# === EM iteration 25 ===
# E-step...
# M-step...
# 	ObjVal = 583.9796861271207
# === EM iteration 26 ===
# E-step...
# M-step...
# 	ObjVal = 582.2401141911445
# === EM iteration 27 ===
# E-step...
# M-step...
# 	ObjVal = 583.382133183316
# === EM iteration 28 ===
# E-step...
# M-step...
# 	ObjVal = 581.628037469844
# === EM iteration 29 ===
# E-step...
# M-step...
# 	ObjVal = 581.9485027456471
# === EM iteration 30 ===
# E-step...
# M-step...
# 	ObjVal = 578.3457153416982
# M = [[1. 0. 0.]
#  [0. 0. 1.]
#  [0. 0. 1.]]
# N = [[0.01 0.99 0.  ]
#  [0.   0.99 0.01]
#  [0.   1.   0.  ]]
# E = [[1.   0.   0.  ]
#  [0.27 0.47 0.25]
#  [0.02 0.   0.98]]
# R[Chris Paul] = [0.91 0.   0.   0.   0.04 0.06]
# R[Devin Booker] = [1. 0. 0. 0. 0. 0.]
# R[Mikal Bridges] = [1. 0. 0. 0. 0. 0.]
# R[Jae Crowder] = [0.99 0.   0.   0.   0.   0.01]
# R[Deandre Ayton] = [1. 0. 0. 0. 0. 0.]
# Final Likelihood = 528.7237595075483
# Optimizing team = DEN
# Initial Likelihood = 596.4028088020597
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.7, 0.2, 0.1],
#        [0.1, 0.7, 0.2],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Monte Morris': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Will Barton': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Jeff Green': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Aaron Gordon': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Nikola Jokic': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2939'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 907.8055931618732
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 888.2350951434903
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 842.4713529327206
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 816.1340768682943
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 780.4112644593639
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 751.6378061602173
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 724.2425417559759
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 709.423634093773
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 696.0233158515828
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 683.214429590134
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 672.6836980400041
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 654.049530448254
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 641.2682534923163
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 634.8093349146909
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 636.4679107479568
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 632.521663061291
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 626.9611093363502
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 621.1478897026906
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 611.7250380361436
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 613.3758631627559
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 611.2890832480452
# M = [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.1  0.84 0.06]
#  [0.02 0.98 0.  ]
#  [0.   1.   0.  ]]
# E = [[0.98 0.   0.02]
#  [0.23 0.4  0.37]
#  [0.48 0.   0.52]]
# R[Monte Morris] = [0.95 0.04 0.   0.01 0.   0.  ]
# R[Will Barton] = [0.99 0.   0.01 0.   0.   0.  ]
# R[Jeff Green] = [0.98 0.   0.   0.   0.02 0.  ]
# R[Aaron Gordon] = [0.96 0.   0.04 0.   0.   0.  ]
# R[Nikola Jokic] = [0.89 0.   0.02 0.   0.   0.09]
# Final Likelihood = 538.5535055760876
# Optimizing team = POR
# Initial Likelihood = 518.1532180470024
# {'M': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Damian Lillard': array([0.5, 0. , 0.2, 0.2, 0.1, 0. ]), 'Anfernee Simons': array([1, 0, 0, 0, 0, 0]), 'Normal Powell': array([1, 0, 0, 0, 0, 0]), 'Robert Covington': array([1, 0, 0, 0, 0, 0]), 'Jusuf Nurkic': array([0.5, 0. , 0.2, 0.2, 0.1, 0. ])}, 'name': 'synthetic-1228'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 777.9843776845353
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 766.4497939364397
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 655.1318011559365
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 642.9267213821594
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 634.5844592741348
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 625.5839541430416
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 617.8260212195814
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 609.0436963060297
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 596.2403643749806
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 586.2717633830063
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 587.7132690731481
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 582.050349399238
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 571.2926167905304
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 570.1974202341638
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 571.2299486200504
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 571.3508643855282
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 571.2399798754404
# M = [[1. 0. 0.]
#  [0. 0. 1.]
#  [0. 0. 1.]]
# N = [[0.05 0.92 0.03]
#  [0.   0.98 0.02]
#  [0.   0.86 0.14]]
# E = [[0.84 0.   0.16]
#  [0.29 0.57 0.14]
#  [0.   0.   1.  ]]
# R[Damian Lillard] = [0.95 0.03 0.   0.   0.02 0.01]
# R[Anfernee Simons] = [1. 0. 0. 0. 0. 0.]
# R[Normal Powell] = [1. 0. 0. 0. 0. 0.]
# R[Robert Covington] = [0.86 0.   0.   0.   0.14 0.  ]
# R[Jusuf Nurkic] = [0.93 0.   0.   0.01 0.01 0.04]
# Final Likelihood = 492.83048156563405
# Optimizing team = SAC
# Initial Likelihood = 325.7206164541239
# {'M': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'N': array([[0.9, 0.1, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.1, 0.9]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {"De'Aaron Fox'": array([0.5, 0. , 0.5, 0. , 0. , 0. ]), 'Tyresse Haliburton': array([0.5, 0.5, 0. , 0. , 0. , 0. ]), 'Maurice Harkless': array([0.5 , 0.25, 0.25, 0.  , 0.  , 0.  ]), 'Harrison Barnes': array([0.5 , 0.25, 0.25, 0.  , 0.  , 0.  ]), 'Chimezie Metu': array([0.5 , 0.25, 0.25, 0.  , 0.  , 0.  ])}, 'name': 'synthetic-1418'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 477.56561388085595
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 425.48955729526295
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 383.16269159966805
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 350.8549489264266
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 340.67830164118493
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 336.23379723520355
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 335.1000917542233
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 331.0829222600949
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 331.23488848745825
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 331.1297710164191
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 330.1098818781432
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 329.0887774510669
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 327.6125227847075
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 332.00405466220366
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 337.1031080318891
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 333.2536657357581
# M = [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# N = [[0.03 0.82 0.15]
#  [0.04 0.86 0.09]
#  [0.   0.64 0.36]]
# E = [[0.99 0.   0.01]
#  [0.01 0.9  0.1 ]
#  [0.32 0.   0.68]]
# R[De'Aaron Fox'] = [0. 1. 0. 0. 0. 0.]
# R[Tyresse Haliburton] = [0. 1. 0. 0. 0. 0.]
# R[Maurice Harkless] = [0.33 0.   0.5  0.15 0.03 0.  ]
# R[Harrison Barnes] = [0.53 0.   0.   0.12 0.27 0.08]
# R[Chimezie Metu] = [0.45 0.   0.34 0.   0.   0.21]
# Final Likelihood = 264.1214330384387
# Optimizing team = UTA
# Initial Likelihood = 588.9489178278629
# {'M': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'N': array([[0.1, 0.2, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.2, 0.1]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Mike Conley': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Donovan Mitchell': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), "Royce O'Neale": array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Bojan Bogdanovic': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Rudy Gobert': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-1583'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 923.894421337666
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 896.2005572289578
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 857.8498894385473
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 817.240994294422
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 788.9713434329597
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 763.6140315151995
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 740.5499668867933
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 720.171675310568
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 672.6357979475487
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 662.3086328747032
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 656.3895669680151
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 649.1042392241245
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 643.1646688461466
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 644.5723918241013
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 637.5866427134162
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 627.4090428843801
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 631.6829827670125
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 631.2445267152863
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 631.9054545398358
# M = [[0.   0.   1.  ]
#  [0.   0.91 0.09]
#  [1.   0.   0.  ]]
# N = [[0.   0.86 0.14]
#  [0.02 0.98 0.  ]
#  [0.02 0.98 0.  ]]
# E = [[0.99 0.01 0.  ]
#  [0.24 0.45 0.32]
#  [0.38 0.   0.62]]
# R[Mike Conley] = [0.8  0.19 0.   0.01 0.   0.  ]
# R[Donovan Mitchell] = [0.85 0.05 0.09 0.   0.   0.01]
# R[Royce O'Neale] = [1. 0. 0. 0. 0. 0.]
# R[Bojan Bogdanovic] = [0.97 0.   0.01 0.01 0.01 0.  ]
# R[Rudy Gobert] = [0.96 0.   0.   0.01 0.04 0.  ]
# Final Likelihood = 533.6813544772258
# Optimizing team = OKC
# Initial Likelihood = 600.0604594121313
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Shai Gilgeous-Alexander': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Luguentz Dort': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Josh Giddey': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Darius Bazley': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Jeremiah Robinson-Earl': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 880.3718506008976
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 854.2070574827045
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 812.9542225425166
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 784.2527369892977
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 751.5759434275897
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 725.1443333581334
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 696.1926735767029
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 675.1119569974851
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 662.7076289066435
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 648.6501412557017
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 637.0148309454631
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 626.6490083857936
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 619.3873571393545
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 608.8934137021868
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 608.1302611199451
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 599.3197435219967
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 594.091609663148
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 591.1868349419549
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 584.9719619292098
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 586.9737737598354
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 582.218861119511
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 579.6513935468768
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 584.4937546021499
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 854.3049583079865
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 820.745557652418
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 791.0474677197218
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 752.9654097169995
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 714.4549615185216
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 688.1246316194677
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 671.2476684339435
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 660.9782545477971
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 638.3853958210559
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 624.9817516745284
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 614.2104311999706
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 609.5307649715714
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 606.3918175136463
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 596.2899550392547
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 598.5958454079832
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 599.3880705060709
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 595.0782778174249
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 597.8541139353292
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 594.0680923019933
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 589.6705112022925
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 587.4383801475494
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 589.1264624931689
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 589.5432783580825
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 589.1364078475315
# M = [[1.   0.   0.  ]
#  [0.   0.98 0.02]
#  [0.84 0.   0.16]]
# N = [[0.11 0.89 0.  ]
#  [0.02 0.98 0.  ]
#  [0.   1.   0.  ]]
# E = [[1.   0.   0.  ]
#  [0.24 0.47 0.28]
#  [0.   0.   1.  ]]
# R[Dejounte Murray] = [0.91 0.07 0.01 0.   0.01 0.01]
# R[Lonnie Walker IV] = [0.99 0.   0.01 0.   0.   0.  ]
# R[Keldon Johnson] = [0.93 0.03 0.03 0.   0.   0.  ]
# R[Doug McDermott] = [1. 0. 0. 0. 0. 0.]
# R[Jakob Poeltl] = [0.9 0.  0.  0.  0.  0.1]
# Final Likelihood = 528.5071590839513
# Optimizing team = ORL
# Initial Likelihood = 581.2106177612493
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Cole Anthony': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Gary Harris': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Franz Wagner': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Wendell Carter Jr.': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Mo Bamba': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 877.2140017785835
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 850.4266751869051
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 815.902162608127
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 782.5566765514628
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 759.762658290321
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 734.2115030208761
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 718.4259033052731
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 697.8374203785194
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 687.5650027279808
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 675.6106292312409
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 661.0542302257458
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 654.403207920609
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 654.5208954541229
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 652.6944122000784
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 624.5665481524727
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 619.2816600698746
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 609.0532347984538
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 607.2252999393083
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 605.1787892564704
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 605.9756289259032
# === EM iteration 25 ===
# E-step...
# M-step...
# 	ObjVal = 600.599914295486
# === EM iteration 26 ===
# E-step...
# M-step...
# 	ObjVal = 601.7099477432398
# === EM iteration 27 ===
# E-step...
# M-step...
# 	ObjVal = 605.6727313930369
# === EM iteration 28 ===
# E-step...
# M-step...
# 	ObjVal = 606.3136631817249
# M = [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.   1.   0.  ]
#  [0.01 0.98 0.01]
#  [0.04 0.83 0.13]]
# E = [[1.   0.   0.  ]
#  [0.26 0.44 0.31]
#  [0.99 0.   0.01]]
# R[Cole Anthony] = [1. 0. 0. 0. 0. 0.]
# R[Gary Harris] = [0.89 0.   0.11 0.   0.   0.  ]
# R[Franz Wagner] = [0.97 0.   0.   0.   0.   0.03]
# R[Wendell Carter Jr.] = [0.95 0.01 0.   0.   0.   0.04]
# R[Mo Bamba] = [0.95 0.04 0.   0.   0.01 0.  ]
# Final Likelihood = 536.2580550280042
# Optimizing team = MIN
# Initial Likelihood = 477.58731232212585
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {"D'Angleo Russell": array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Anthony Edwards': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Leandro Bolmaro': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Jarred Vanderbilt': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Karl-Anthony Towns': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 751.3763636674029
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 671.8220055930444
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 628.6122698166331
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 611.7416723381815
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 611.31099521752
# M = [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.16 0.73 0.11]
#  [0.22 0.67 0.11]
#  [0.16 0.64 0.19]]
# E = [[0.82 0.01 0.17]
#  [0.09 0.73 0.19]
#  [0.24 0.   0.75]]
# R[D'Angleo Russell] = [0. 1. 0. 0. 0. 0.]
# R[Anthony Edwards] = [0.73 0.02 0.11 0.   0.07 0.08]
# R[Leandro Bolmaro] = [0. 1. 0. 0. 0. 0.]
# R[Jarred Vanderbilt] = [0.77 0.12 0.   0.   0.06 0.05]
# R[Karl-Anthony Towns] = [0.69 0.15 0.   0.   0.   0.16]
# Final Likelihood = 428.7809166907327
# Optimizing team = HOU
# Initial Likelihood = 514.546523098316
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Kevin Porter Jr.': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Jalen Green': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'KJ Martin': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), "Jae'Sean Tate": array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Christian Wood': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 766.8056638708691
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 714.5470118687151
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 670.0729317076696
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 634.0113225329462
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 621.3566236812376
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 603.3105151221212
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 588.6750878757065
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 581.0214586162462
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 578.1170097721899
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 577.0300548339006
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 573.0068476191873
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 569.9351045202208
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 566.912486675706
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 567.2874010651414
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 569.2380864890008
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 567.1580139725327
# M = [[0.65 0.35 0.  ]
#  [0.   1.   0.  ]
#  [1.   0.   0.  ]]
# N = [[0.15 0.85 0.  ]
#  [0.1  0.88 0.02]
#  [0.02 0.98 0.  ]]
# E = [[0.94 0.   0.06]
#  [0.15 0.6  0.25]
#  [0.   0.   1.  ]]
# R[Kevin Porter Jr.] = [0.   0.39 0.   0.61 0.01 0.  ]
# R[Jalen Green] = [0.   0.   0.19 0.81 0.   0.  ]
# R[KJ Martin] = [0. 0. 0. 1. 0. 0.]
# R[Jae'Sean Tate] = [0.81 0.01 0.09 0.09 0.   0.  ]
# R[Christian Wood] = [0.   0.   0.03 0.69 0.16 0.12]
# Final Likelihood = 481.46065916964517
# Optimizing team = NOP
# Initial Likelihood = 542.714139983451
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {"Devonte' Graham": array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Josh Hart': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Brandon Ingram': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Herbert Jones': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Jonas Valanciunas': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 824.6934737791393
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 793.4570987759874
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 766.1112395679351
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 725.2075459013562
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 626.0281498842058
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 613.6766089938727
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 599.2550936548552
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 589.0234996689015
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 586.2915325464186
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 573.1106616670542
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 561.9286312675504
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 559.3551647695721
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 552.8535280340823
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 552.8197595276981
# M = [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.15 0.83 0.02]
#  [0.   0.99 0.  ]
#  [0.   1.   0.  ]]
# E = [[0.78 0.03 0.19]
#  [0.23 0.52 0.25]
#  [0.36 0.   0.64]]
# R[Devonte' Graham] = [0.91 0.09 0.   0.   0.   0.  ]
# R[Josh Hart] = [1. 0. 0. 0. 0. 0.]
# R[Brandon Ingram] = [1. 0. 0. 0. 0. 0.]
# R[Herbert Jones] = [1. 0. 0. 0. 0. 0.]
# R[Jonas Valanciunas] = [0.97 0.01 0.   0.02 0.   0.  ]
# Final Likelihood = 514.2872694422882
# Optimizing team = PHI
# Initial Likelihood = 511.4058565584701
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Tyrese Maxey': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Matisse Thybulle': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Danny Green': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Tobias Harris': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Joel Embiid': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 780.429436536988
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 754.5704615764737
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 723.966578545282
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 680.5708387022198
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 665.9601722580976
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 643.4914741551344
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 619.1558379258258
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 601.6581125028708
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 591.3190052979929
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 581.5198897894534
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 575.4158473034697
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 568.2734605143125
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 568.5955485853765
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 572.4947155814243
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 575.7454261055035
# M = [[0.83 0.   0.17]
#  [0.   1.   0.  ]
#  [1.   0.   0.  ]]
# N = [[0.04 0.91 0.05]
#  [0.01 0.99 0.01]
#  [0.   0.95 0.05]]
# E = [[0.89 0.   0.11]
#  [0.14 0.6  0.27]
#  [0.07 0.   0.93]]
# R[Tyrese Maxey] = [0.64 0.05 0.   0.19 0.   0.12]
# R[Matisse Thybulle] = [0.98 0.   0.   0.   0.02 0.  ]
# R[Danny Green] = [0.99 0.   0.   0.01 0.   0.  ]
# R[Tobias Harris] = [0.81 0.   0.   0.   0.19 0.  ]
# R[Joel Embiid] = [0.73 0.   0.   0.   0.03 0.24]
# Final Likelihood = 479.59966044489505
# Optimizing team = MEM
# Initial Likelihood = 543.7073431669185
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Ja Morant': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Desmond Bane': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Ziaire Williams': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Jaren Jackson Jr.': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Steven Adams': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 835.5972209026204
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 798.9843909668832
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 772.9015103551428
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 744.5594640002153
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 711.0160101209266
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 689.9634641656846
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 661.4526817634285
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 642.7125707235793
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 628.9197470250958
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 603.5577266373415
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 601.5311075741226
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 594.0445804083006
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 593.6669683985007
# M = [[0.87 0.   0.13]
#  [0.   0.99 0.01]
#  [1.   0.   0.  ]]
# N = [[0.15 0.85 0.  ]
#  [0.02 0.98 0.01]
#  [0.05 0.95 0.  ]]
# E = [[1.   0.   0.  ]
#  [0.23 0.51 0.25]
#  [0.51 0.   0.49]]
# R[Ja Morant] = [0.8 0.2 0.  0.  0.  0. ]
# R[Desmond Bane] = [0.88 0.1  0.   0.   0.02 0.  ]
# R[Ziaire Williams] = [1. 0. 0. 0. 0. 0.]
# R[Jaren Jackson Jr.] = [0.97 0.   0.   0.03 0.   0.  ]
# R[Steven Adams] = [0.96 0.   0.   0.   0.   0.03]
# Final Likelihood = 514.0360761216629
# Optimizing team = CLE
# Initial Likelihood = 407.5198463741693
# {'M': array([[0.6, 0.3, 0.1],
#        [0.2, 0.6, 0.2],
#        [0.1, 0.3, 0.6]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Darius Garland': array([0.5, 0. , 0.2, 0. , 0.2, 0.1]), 'Lauri Markanen': array([1, 0, 0, 0, 0, 0]), 'Isaac Okoro': array([0.5, 0. , 0.2, 0. , 0.2, 0.1]), 'Evab Mobley': array([1, 0, 0, 0, 0, 0]), 'Jarrett Allen': array([1, 0, 0, 0, 0, 0])}, 'name': 'synthetic-100'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 636.5623795155494
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 588.116478045542
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 543.6146001008037
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 515.8261183864732
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 498.31733800797576
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 492.99966957748273
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 490.73099589064475
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 485.21987395795793
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 482.92541932429833
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 480.71276153211073
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 480.4163050336798
# M = [[1.   0.   0.  ]
#  [0.68 0.   0.32]
#  [0.   0.   1.  ]]
# N = [[0.2  0.71 0.09]
#  [0.   1.   0.  ]
#  [0.05 0.8  0.15]]
# E = [[0.86 0.   0.14]
#  [0.07 0.8  0.13]
#  [0.33 0.   0.67]]
# R[Darius Garland] = [0.68 0.18 0.   0.   0.05 0.09]
# R[Lauri Markanen] = [1. 0. 0. 0. 0. 0.]
# R[Isaac Okoro] = [0.98 0.02 0.   0.   0.   0.  ]
# R[Evab Mobley] = [1. 0. 0. 0. 0. 0.]
# R[Jarrett Allen] = [0.74 0.   0.   0.13 0.   0.14]
# Final Likelihood = 368.8255144956226
# Optimizing team = NYK
# Initial Likelihood = 619.0696246890882
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.9, 0.1, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.1, 0.9]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Immanuel Quickley': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Evan Fournier': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'RJ Barrett': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Julius Randle': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Mitchell Robinson': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2487'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 896.6853171470426
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 880.4717977143803
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 849.3363326928622
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 818.6040365423162
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 783.9964347948016
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 754.7963417071545
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 731.634208396253
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 711.7081810960451
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 697.1470570666347
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 669.5121264648594
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 644.07199933278
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 629.1610704841765
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 624.8073195681018
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 614.0957099787435
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 610.861386153134
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 610.4566460576791
# M = [[0. 0. 1.]
#  [1. 0. 0.]
#  [1. 0. 0.]]
# N = [[0.03 0.93 0.04]
#  [0.01 0.98 0.01]
#  [0.   1.   0.  ]]
# E = [[0.93 0.02 0.05]
#  [0.37 0.36 0.26]
#  [0.21 0.15 0.63]]
# R[Immanuel Quickley] = [0.99 0.   0.   0.   0.   0.  ]
# R[Evan Fournier] = [1. 0. 0. 0. 0. 0.]
# R[RJ Barrett] = [0.98 0.   0.01 0.   0.   0.  ]
# R[Julius Randle] = [0.95 0.   0.   0.   0.   0.05]
# R[Mitchell Robinson] = [1. 0. 0. 0. 0. 0.]
# Final Likelihood = 541.3793734632015
# Optimizing team = BOS
# Initial Likelihood = 500.3622537257429
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.9, 0.1, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.1, 0.9]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Marcus Smart': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Jaylen Brown': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Jayson Tatum': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Grant Williams': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Al Hordford': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2487'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 781.0768798292436
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 717.7960862212907
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 682.9840235625555
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 668.4562363562634
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 655.8319253930862
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 642.181663345724
# M = [[0.09 0.   0.91]
#  [0.   1.   0.  ]
#  [1.   0.   0.  ]]
# N = [[0.01 0.92 0.07]
#  [0.08 0.82 0.1 ]
#  [0.12 0.72 0.16]]
# E = [[0.65 0.01 0.35]
#  [0.19 0.63 0.18]
#  [0.31 0.   0.69]]
# R[Marcus Smart] = [0.62 0.09 0.   0.03 0.   0.26]
# R[Jaylen Brown] = [0.  0.  0.3 0.  0.  0.7]
# R[Jayson Tatum] = [0.6  0.02 0.04 0.05 0.29 0.  ]
# R[Grant Williams] = [0.35 0.   0.05 0.03 0.03 0.55]
# R[Al Hordford] = [0. 0. 0. 0. 0. 1.]
# Final Likelihood = 474.8848991117549
# Optimizing team = TOR
# Initial Likelihood = 571.1654105261808
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Fred VanVleet': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Gary Trent Jr.': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'OG Anunoby': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Scottie Barnes': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Precious Achiuwa': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 852.4084591738041
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 829.460011420452
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 793.9586021202446
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 768.5287201272197
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 740.599711772979
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 719.9222177785316
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 698.7365806865898
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 681.1494206130762
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 665.7729818370142
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 654.6342861259543
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 647.9633167478745
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 641.2910553066545
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 645.5861404195671
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 647.5311718565667
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 637.5765579516222
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 625.3974757714913
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 618.2409609401382
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 616.7771226690946
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 615.690354473861
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 609.7594228282103
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 602.9050328045325
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 590.5635627541947
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 586.059557759405
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 590.3903504115739
# === EM iteration 25 ===
# E-step...
# M-step...
# 	ObjVal = 591.1766750964928
# === EM iteration 26 ===
# E-step...
# M-step...
# 	ObjVal = 589.2370622997539
# M = [[0.01 0.   0.99]
#  [0.   1.   0.  ]
#  [1.   0.   0.  ]]
# N = [[0.   0.94 0.06]
#  [0.01 0.99 0.01]
#  [0.03 0.97 0.  ]]
# E = [[0.75 0.   0.25]
#  [0.24 0.47 0.28]
#  [0.31 0.   0.69]]
# R[Fred VanVleet] = [0.95 0.04 0.   0.   0.01 0.  ]
# R[Gary Trent Jr.] = [0.94 0.   0.05 0.   0.01 0.  ]
# R[OG Anunoby] = [0.97 0.   0.   0.03 0.   0.  ]
# R[Scottie Barnes] = [0.98 0.01 0.   0.   0.   0.  ]
# R[Precious Achiuwa] = [0.99 0.   0.   0.   0.   0.01]
# Final Likelihood = 529.6278966368611
# Optimizing team = WAS
# Initial Likelihood = 581.3516625007903
# {'M': array([[0.6, 0.3, 0.1],
#        [0.2, 0.6, 0.2],
#        [0.1, 0.3, 0.6]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
# ...
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 843.8875372554583
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 812.4351295577083
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 788.1236722231516
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 752.8533725736736
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 726.2126958392146
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 698.1740608169633
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 681.2900677622712
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 675.0968874251132
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 665.2904552922337
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 656.9835446027648
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 648.1448585455609
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 634.9395273070093
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 637.358814817733
# M = [[0.   0.   1.  ]
#  [1.   0.   0.  ]
#  [0.75 0.   0.25]]
# N = [[0.06 0.83 0.11]
#  [0.01 0.98 0.01]
#  [0.04 0.89 0.07]]
# E = [[0.54 0.   0.46]
#  [0.25 0.5  0.24]
#  [0.15 0.   0.85]]
# R[Coby White] = [1. 0. 0. 0. 0. 0.]
# R[Zach LaVine] = [0.88 0.   0.04 0.08 0.   0.  ]
# R[Javonte Green] = [1. 0. 0. 0. 0. 0.]
# R[DeMar DeRozan] = [0.81 0.   0.   0.   0.11 0.08]
# R[Nikola Vucevic] = [1. 0. 0. 0. 0. 0.]
# Final Likelihood = 517.5013974656353
# Optimizing team = CHA
# Initial Likelihood = 561.6816479657807
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.7, 0.2, 0.1],
#        [0.1, 0.7, 0.2],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'LaMelo Ball': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Terry Rozier': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Kelly Oubre Jr.': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Miles Bridges': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Mason Plumlee': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2939'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 883.1525163738752
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 857.147993465673
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 830.051661835733
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 802.3478736537649
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 766.1596822307174
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 740.8156771954267
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 717.0302359316147
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 692.9517510667089
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 673.9984788931511
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 660.7092823359844
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 660.0744060001723
# M = [[1. 0. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]
# N = [[0.09 0.9  0.01]
#  [0.02 0.95 0.03]
#  [0.01 0.98 0.01]]
# E = [[0.82 0.01 0.17]
#  [0.26 0.48 0.26]
#  [0.05 0.17 0.78]]
# R[LaMelo Ball] = [0.97 0.   0.   0.02 0.   0.01]
# R[Terry Rozier] = [0.97 0.   0.02 0.   0.   0.  ]
# R[Kelly Oubre Jr.] = [0.96 0.03 0.   0.   0.   0.  ]
# R[Miles Bridges] = [0.94 0.   0.06 0.   0.   0.  ]
# R[Mason Plumlee] = [1. 0. 0. 0. 0. 0.]
# Final Likelihood = 530.8639187981956
# Optimizing team = IND
# Initial Likelihood = 550.840170405772
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Malcolm Brogdon': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Chris Duarte': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Oshae Brissett': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Domantas Sabonis': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Myles Turner': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 841.0181773000253
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 811.7206862411385
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 776.2212692230519
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 745.1635423367395
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 718.4311494166643
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 694.2775840177468
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 673.0257963338391
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 654.2538836849604
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 648.0071627964846
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 634.4047752866685
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 626.938720245488
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 616.4048626237146
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 610.4223523924773
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 603.17074175372
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 600.380491405617
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 596.0800850778853
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 600.5504914537253
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 597.8831460466474
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 595.6185812325068
# M = [[0. 0. 1.]
#  [0. 0. 1.]
#  [1. 0. 0.]]
# N = [[0.   0.94 0.06]
#  [0.   0.98 0.01]
#  [0.04 0.96 0.  ]]
# E = [[1.   0.   0.  ]
#  [0.26 0.49 0.26]
#  [0.39 0.   0.61]]
# R[Malcolm Brogdon] = [1. 0. 0. 0. 0. 0.]
# R[Chris Duarte] = [0.97 0.   0.03 0.   0.   0.  ]
# R[Oshae Brissett] = [1. 0. 0. 0. 0. 0.]
# R[Domantas Sabonis] = [0.92 0.01 0.   0.   0.07 0.  ]
# R[Myles Turner] = [0.98 0.   0.   0.01 0.   0.01]
# Final Likelihood = 527.071713054198
# Optimizing team = LAL
# Initial Likelihood = 614.4050606609281
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Russell Westbrook': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Malik Monk': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'LeBron James': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Carmelo Anthony': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Anthony Davis': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 882.3928917005909
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 854.9484477616967
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 806.1908480971861
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 772.5358483413232
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 740.4827027593019
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 712.1742510607091
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 637.9065444051489
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 636.0488476914618
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 624.0799105874956
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 611.4488331319361
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 606.213015987431
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 602.4805111841031
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 599.5668794322394
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 588.5233120378671
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 583.7214157163704
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 581.9430692826552
# === EM iteration 20 ===
# E-step...
# M-step...
# 	ObjVal = 581.1100753012676
# === EM iteration 21 ===
# E-step...
# M-step...
# 	ObjVal = 574.6628538991628
# === EM iteration 22 ===
# E-step...
# M-step...
# 	ObjVal = 569.8296261962332
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 565.4373943846219
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 563.081135265376
# === EM iteration 25 ===
# E-step...
# M-step...
# 	ObjVal = 563.5072702217478
# === EM iteration 26 ===
# E-step...
# M-step...
# 	ObjVal = 561.4088951906355
# === EM iteration 27 ===
# E-step...
# M-step...
# 	ObjVal = 562.6185594574979
# === EM iteration 28 ===
# E-step...
# M-step...
# 	ObjVal = 562.0267058260922
# === EM iteration 29 ===
# E-step...
# M-step...
# 	ObjVal = 562.065717800324
# M = [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.   1.   0.  ]
#  [0.   1.   0.  ]
#  [0.   0.84 0.16]]
# E = [[1.   0.   0.  ]
#  [0.3  0.39 0.31]
#  [1.   0.   0.  ]]
# R[Russell Westbrook] = [1. 0. 0. 0. 0. 0.]
# R[Malik Monk] = [1. 0. 0. 0. 0. 0.]
# R[LeBron James] = [0.85 0.   0.   0.15 0.   0.  ]
# R[Carmelo Anthony] = [0.99 0.   0.01 0.   0.   0.  ]
# R[Anthony Davis] = [1. 0. 0. 0. 0. 0.]
# Final Likelihood = 543.0799971115503
# Optimizing team = GSW
# Initial Likelihood = 623.0371422113508
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.9, 0.1, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.1, 0.9]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Stephen Curry': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Jordan Poole': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Andrew Wiggins': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Otto Porter Jr.': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Kevon Looney': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2487'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 905.4838168562644
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 874.9202164343326
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 831.1727753906462
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 792.2338149011488
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 762.9866289336736
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 726.3958545603294
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 702.4623919401494
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 669.8717964415048
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 656.4494742418086
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 653.8777023783384
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 648.9669970808027
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 639.3776442454616
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 634.062453374816
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 632.6020225753934
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 628.2785846107806
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 625.2556009914249
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 621.9904334035908
# === EM iteration 18 ===
# E-step...
# M-step...
# 	ObjVal = 620.422789733912
# === EM iteration 19 ===
# E-step...
# M-step...
# 	ObjVal = 604.703205418719
# === EM iteration 23 ===
# E-step...
# M-step...
# 	ObjVal = 601.8362399395704
# === EM iteration 24 ===
# E-step...
# M-step...
# 	ObjVal = 598.7665925653776
# === EM iteration 25 ===
# E-step...
# M-step...
# 	ObjVal = 599.3519790371721
# === EM iteration 26 ===
# E-step...
# M-step...
# 	ObjVal = 601.8252879036464
# === EM iteration 27 ===
# E-step...
# M-step...
# 	ObjVal = 599.3948041000128
# M = [[0.   0.   1.  ]
#  [0.02 0.98 0.  ]
#  [1.   0.   0.  ]]
# N = [[0.   0.82 0.18]
#  [0.   1.   0.  ]
#  [0.   0.98 0.02]]
# E = [[0.99 0.   0.01]
#  [0.31 0.39 0.3 ]
#  [0.   0.   1.  ]]
# R[Stephen Curry] = [0.83 0.   0.16 0.   0.   0.  ]
# R[Jordan Poole] = [0.95 0.05 0.   0.   0.   0.  ]
# R[Andrew Wiggins] = [0.89 0.   0.   0.   0.11 0.  ]
# R[Otto Porter Jr.] = [1. 0. 0. 0. 0. 0.]
# R[Kevon Looney] = [0.99 0.   0.   0.   0.   0.  ]
# Final Likelihood = 540.0064582738554
# Optimizing team = MIL
# Initial Likelihood = 529.3989098663777
# {'M': array([[0. , 0.3, 0.7],
#        [0.2, 0.6, 0.2],
#        [0.7, 0.3, 0. ]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Jrue Holiday': array([0.8, 0.2, 0. , 0. , 0. , 0. ]), 'Grayson Allen': array([0.8, 0. , 0.2, 0. , 0. , 0. ]), 'Khris Middleton': array([0.8, 0. , 0. , 0.2, 0. , 0. ]), 'Giannis Antetokounmpo': array([0.8, 0. , 0. , 0. , 0.2, 0. ]), 'Bobby Portis': array([0.8, 0. , 0. , 0. , 0. , 0.2])}, 'name': 'synthetic-2261'}
# === EM iteration 1 ===
# E-step...
# M-step...
# 	ObjVal = 814.1849195660755
# === EM iteration 2 ===
# E-step...
# M-step...
# 	ObjVal = 787.8698996368278
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 752.1960322169773
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 724.8068888517629
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 696.0273403248057
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 675.70028897374
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 666.6979412879313
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 657.9615041424023
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 641.5295130133698
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 639.0472249175089
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 632.494412110927
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 621.5932307902293
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 615.9408751668014
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 614.1609504393695
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 618.0248790970808
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 613.7605443668547
# M = [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# N = [[0.02 0.96 0.02]
#  [0.02 0.96 0.02]
#  [0.17 0.83 0.  ]]
# E = [[0.84 0.   0.16]
#  [0.18 0.54 0.27]
#  [0.08 0.01 0.91]]
# R[Jrue Holiday] = [0.97 0.03 0.   0.01 0.   0.  ]
# R[Grayson Allen] = [0.97 0.   0.02 0.   0.   0.  ]
# R[Khris Middleton] = [0.95 0.05 0.   0.   0.   0.  ]
# R[Giannis Antetokounmpo] = [0.87 0.   0.   0.02 0.12 0.  ]
# R[Bobby Portis] = [0.87 0.1  0.   0.   0.   0.03]
# Final Likelihood = 507.75050894329974
# Optimizing team = BKN
# Initial Likelihood = 252.02426293437148
# {'M': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'N': array([[0.8, 0.2, 0. ],
#        [0.1, 0.8, 0.1],
#        [0. , 0.2, 0.8]]), 'E': array([[0.7, 0.2, 0.1],
#        [0.1, 0.8, 0.1],
#        [0.1, 0.2, 0.7]]), 'R': {'Spencer Dinwiddie': array([0.5, 0. , 0. , 0. , 0.5, 0. ]), 'Cam Thomas': array([0.5 , 0.25, 0.  , 0.  , 0.25, 0.  ]), 'Mikal Bridges': array([0.5 , 0.25, 0.  , 0.  , 0.25, 0.  ]), 'Dorian Finney-Smith': array([0.5, 0.5, 0. , 0. , 0. , 0. ]), 'Nic Claxton': array([0.5 , 0.25, 0.  , 0.  , 0.25, 0.  ])}, 'name': 'synthetic-1194'}
# === EM iteration 1 ===
# E-step...
# M-step...
# Solver 'MOSEK' failed. Try another solver, or solve with verbose=True for more information.
# 	ObjVal = 1e+100
# === EM iteration 2 ===
# E-step...
# M-step...
# Solver 'MOSEK' failed. Try another solver, or solve with verbose=True for more information.
# 	ObjVal = 1e+100
# === EM iteration 3 ===
# E-step...
# M-step...
# 	ObjVal = 327.10988214694567
# === EM iteration 4 ===
# E-step...
# M-step...
# 	ObjVal = 278.8146197121616
# === EM iteration 5 ===
# E-step...
# M-step...
# 	ObjVal = 241.3857653460159
# === EM iteration 6 ===
# E-step...
# M-step...
# 	ObjVal = 218.9206220426684
# === EM iteration 7 ===
# E-step...
# M-step...
# 	ObjVal = 207.19823516149177
# === EM iteration 8 ===
# E-step...
# M-step...
# 	ObjVal = 200.41425310767804
# === EM iteration 9 ===
# E-step...
# M-step...
# 	ObjVal = 199.2699820279759
# === EM iteration 10 ===
# E-step...
# M-step...
# 	ObjVal = 199.83094813783288
# === EM iteration 11 ===
# E-step...
# M-step...
# 	ObjVal = 198.1960336174979
# === EM iteration 12 ===
# E-step...
# M-step...
# 	ObjVal = 197.35599525069182
# === EM iteration 13 ===
# E-step...
# M-step...
# 	ObjVal = 196.5819566520189
# === EM iteration 14 ===
# E-step...
# M-step...
# 	ObjVal = 193.203498743626
# === EM iteration 15 ===
# E-step...
# M-step...
# 	ObjVal = 193.21927485768816
# === EM iteration 16 ===
# E-step...
# M-step...
# 	ObjVal = 194.6071957891373
# === EM iteration 17 ===
# E-step...
# M-step...
# 	ObjVal = 195.5945625369153
# M = [[0.  0.  1. ]
#  [0.  1.  0. ]
#  [0.4 0.6 0. ]]
# N = [[0.   0.49 0.51]
#  [0.03 0.9  0.07]
#  [0.   0.59 0.41]]
# E = [[0.93 0.   0.07]
#  [0.01 0.96 0.03]
#  [0.62 0.   0.38]]
# R[Spencer Dinwiddie] = [0.  0.5 0.  0.  0.5 0. ]
# R[Cam Thomas] = [0.61 0.   0.3  0.1  0.   0.  ]
# R[Mikal Bridges] = [0.   0.11 0.   0.78 0.11 0.  ]
# R[Dorian Finney-Smith] = [0.  0.5 0.  0.  0.5 0. ]
# R[Nic Claxton] = [0.4  0.   0.05 0.   0.31 0.23]
# Final Likelihood = 157.3873723787909

# %%
players
# Out:
# ['Spencer Dinwiddie',
#  'Cam Thomas',
#  'Mikal Bridges',
#  'Dorian Finney-Smith',
#  'Nic Claxton']
